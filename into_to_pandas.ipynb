# %% [markdown]
# # Intro to Pandas 🐼
#
# Documentation: https://pandas.pydata.org/docs/index.html

# %% [markdown]
# ## What's Pandas?
#
# The pandas library is a popular open-source data manipulation and analysis tool for Python.
#
# We use pandas in data science because it provides powerful tools for data manipulation, cleaning, analysis, and visualization, allowing us to work with tabular and structured data more efficiently and effectively.

# %%
import pandas as pd

# %% [markdown]
# ## What's a DataFrame?
#
# A dataframe is a 2-dimensional labeled data structure in pandas that consists of rows and columns, similar to a spreadsheet or SQL table.

# %%
data = {'Name': ['Bamboo', 'Ming Ming', 'Giant', 'Xiong Mao'],
        'Age': [4, 6, 3, 5],
        'Color': ['Black and White', 'Brown', 'White', 'Black'],
        'Favorite Food': ['Bamboo', 'Bamboo shoots', 'Apples', 'Fish'],
        'Weight (lbs)': [220, 180, 300, 250]}

# %%
df = pd.DataFrame(data)
df
# Out:
#         Name  Age            Color  Favorite Food  Weight (lbs)
# 0     Bamboo    4  Black and White         Bamboo           220
# 1  Ming Ming    6            Brown  Bamboo shoots           180
# 2      Giant    3            White         Apples           300
# 3  Xiong Mao    5            Black           Fish           250

# %% [markdown]
# ### What's a Series?
#
# A series is a one-dimensional labeled data structure in pandas that can hold any data type, such as integers, floats, strings, and more

# %%
df["Name"] # df.Name
# Out:
# 0       Bamboo
# 1    Ming Ming
# 2        Giant
# 3    Xiong Mao
# Name: Name, dtype: object

# %% [markdown]
# ### What's an Index?
#
# A dataframe index is a unique identifier for each row in a pandas DataFrame, allowing for easy and efficient access and manipulation of data.

# %%
df.index.values
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# ---

# %% [markdown]
# ## How to read a CSV file?

# %%
# Most Authentic Count of Suicide Bombing Attacks in Pakistan (1995-2016)
# Source: https://www.kaggle.com/datasets/zusmani/pakistansuicideattacks

df = pd.read_csv('PakistanSuicideAttacks.csv', encoding='Windows-1252')

# %% [markdown]
# ## Let's Explore the Data 💣

# %%
df.head() 
# df.tail()
# df.sample(5)
# Out:
#    S#                     Date                   Islamic Date Blast Day Type  \
# 0   1  Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H        Holiday
# 1   2   Monday-November 6-2000           10 SHa`baan 1421 A.H    Working Day
# 2   3     Wednesday-May 8-2002              25 safar 1423 A.H    Working Day
# 3   4      Friday-June 14-2002     3 Raby` al-THaany 1423 A.H    Working Day
# 4   5       Friday-July 4-2003     4 Jumaada al-awal 1424 A.H    Working Day
#
#   Holiday Type         Time       City  Latitude Longitude     Province  ...  \
# 0      Weekend          NaN  Islamabad   33.7180   73.0718      Capital  ...
# 1          NaN          NaN    Karachi   24.9918   66.9911        Sindh  ...
# 2          NaN      7:45 AM   Karachi    24.9918   66.9911        Sindh  ...
# 3          NaN  11:10:00 AM    Karachi   24.9918   66.9911        Sindh  ...
# 4          NaN          NaN     Quetta   30.2095   67.0182  Baluchistan  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   S#                       492 non-null    int64
#  1   Date                     492 non-null    object
#  2   Islamic Date             336 non-null    object
#  3   Blast Day Type           481 non-null    object
#  4   Holiday Type             72 non-null     object
#  5   Time                     281 non-null    object
#  6   City                     492 non-null    object
#  7   Latitude                 490 non-null    float64
#  8   Longitude                490 non-null    object
#  9   Province                 492 non-null    object
#  10  Location                 489 non-null    object
#  11  Location Category        457 non-null    object
#  12  Location Sensitivity     456 non-null    object
#  13  Open/Closed Space        457 non-null    object
# ...

# %%
df.describe()
# Out:
#                S#    Latitude  Killed Min  Killed Max  Injured Min  \
# count  492.000000  490.000000  346.000000   476.00000   361.000000
# mean   246.500000   32.621874   14.855491    15.30042    31.601108
# std    142.172431    2.477845   17.659154    20.32867    38.762832
# min      1.000000   24.879503    0.000000     0.00000     0.000000
# 25%    123.750000   31.823800    3.000000     3.00000     7.000000
# 50%    246.500000   33.583300    8.000000     8.00000    20.000000
# 75%    369.250000   34.004300   20.750000    19.00000    40.000000
# max    492.000000   35.383300  125.000000   148.00000   320.000000
#
#        No. of Suicide Blasts  Temperature(C)  Temperature(F)
# count             410.000000      487.000000      485.000000
# mean                1.117073       21.075554       69.906373
# std                 0.396749        8.390859       15.108953
# min                 1.000000       -2.370000       27.734000
# ...

# %%
df.columns
# Out:
# Index(['S#', 'Date', 'Islamic Date', 'Blast Day Type', 'Holiday Type', 'Time',
#        'City', 'Latitude', 'Longitude', 'Province', 'Location',
#        'Location Category', 'Location Sensitivity', 'Open/Closed Space',
#        'Influencing Event/Event', 'Target Type', 'Targeted Sect if any',
#        'Killed Min', 'Killed Max', 'Injured Min', 'Injured Max',
#        'No. of Suicide Blasts', 'Explosive Weight (max)', 'Hospital Names',
#        'Temperature(C)', 'Temperature(F)'],
#       dtype='object')

# %%
df.shape # df.shape[0] or df.shape[1]
# Out:
# (492, 26)

# %% [markdown]
# ---

# %% [markdown]
# ## Select a subset of a Dataframe

# %% [markdown]
# ### Select column(s) (and rows)

# %%
df["Location Category"] # select 1 column as Series
df[["Location Category"]] # select 1 column as DataFrame
df[["Location Category", "Influencing Event/Event"]] # select multiple columns
# Out:
#     Location Category                            Influencing Event/Event
# 0             Foreign                                                NaN
# 1     Office Building                                                NaN
# 2               Hotel                                                NaN
# 3             Foreign                                                NaN
# 4           Religious                               during Friday prayer
# ..                ...                                                ...
# 487          Military  suicide bomber riding on a motorcycle hit a Fr...
# 488          Military        bomb struck in southwestern Chaman province
# 489               NaN                                                NaN
# 490               NaN  the attacker had been carrying 25kg of “incend...
# 491         Religious                          at the entrance of shrine
#
# [492 rows x 2 columns]

# %%
# select topo three rows and ten first columns
df.iloc[0:3, :10]
# Out:
#    S#                     Date                   Islamic Date Blast Day Type  \
# 0   1  Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H        Holiday
# 1   2   Monday-November 6-2000           10 SHa`baan 1421 A.H    Working Day
# 2   3     Wednesday-May 8-2002              25 safar 1423 A.H    Working Day
#
#   Holiday Type     Time       City  Latitude Longitude Province
# 0      Weekend      NaN  Islamabad   33.7180   73.0718  Capital
# 1          NaN      NaN    Karachi   24.9918   66.9911    Sindh
# 2          NaN  7:45 AM   Karachi    24.9918   66.9911    Sindh

# %% [markdown]
# ### Select unique values

# %%
df["Holiday Type"].unique()
# Out:
# array(['Weekend', nan, 'Christmas/birthday of Quaid-e-Azam', 'Ashura',
#        'Eid Milad un-Nabi', 'Iqbal Day', 'Eid-ul-azha', 'Labour Day',
#        'Eid-ul-Fitar', 'Pakistan Day', 'Defence Day',
#        'Christmas/ birthday of Quaid-e-Azam', 'General Elections',
#        'Eid Holidays', 'Ashura Holiday', 'Eid ul Azha Holiday'],
#       dtype=object)

# %%
# Count unique values
df['Influencing Event/Event'].value_counts().head(10)
# Out:
# Sectarian strife                                                   7
# Muharram Procession                                                4
# Military convoy                                                    4
# Shia Religious Gathering                                           2
# Army convoy                                                        2
# Search operation of Security forces                                2
# military convoy                                                    2
# Sucide bomber wearing an explosive vest carried out the attack.    2
# Military Convoy                                                    2
# Tribal elder Malik Habibullah Khan was the target                  1
# Name: Influencing Event/Event, dtype: int64

# %% [markdown]
# ### Conditions

# %%
df[df['Influencing Event/Event'] == "Sectarian strife"]
# Out:
#       S#                      Date Islamic Date Blast Day Type Holiday Type  \
# 392  393       Friday-June 21-2013          NaN    Working Day          NaN
# 393  394       Sunday-June 30-2013          NaN        Holiday      Weekend
# 406  407  Tuesday-December 17-2013          NaN    Working Day          NaN
# 409  410  Wednesday-January 1-2014          NaN    Working Day          NaN
# 410  411     Monday-January 6-2014          NaN    Working Day          NaN
# 415  416   Tuesday-February 4-2014          NaN    Working Day          NaN
# 419  420   Monday-February 24-2014          NaN    Working Day          NaN
#
#         Time        City  Latitude Longitude     Province  ...  \
# 392      NaN    Peshawar   34.0043   71.5448          KPK  ...
# 393  Evening      Quetta   30.2095   67.0182  Baluchistan  ...
# 406  Evening  Rawalpindi   33.6058   73.0437       Punjab  ...
# 409      NaN      Quetta   30.2095   67.0182  Baluchistan  ...
# ...

# %% [markdown]
# ### Mutliple condtions

# %%
df[(df['Influencing Event/Event'] == "Sectarian strife") & (df["City"] == "Peshawar")]
# Out:
#       S#                     Date Islamic Date Blast Day Type Holiday Type  \
# 392  393      Friday-June 21-2013          NaN    Working Day          NaN
# 415  416  Tuesday-February 4-2014          NaN    Working Day          NaN
# 419  420  Monday-February 24-2014          NaN    Working Day          NaN
#
#     Time      City  Latitude Longitude Province  ... Targeted Sect if any  \
# 392  NaN  Peshawar   34.0043   71.5448      KPK  ...               Shiite
# 415  NaN  Peshawar   34.0043   71.5448      KPK  ...                 None
# 419  NaN  Peshawar   34.0043   71.5448      KPK  ...                 None
#
#     Killed Min Killed Max Injured Min Injured Max No. of Suicide Blasts  \
# 392       14.0       15.0        28.0          30                   NaN
# 415        9.0        9.0        25.0          50                   NaN
# 419        2.0        3.0         8.0          10                   NaN
#
#     Explosive Weight (max)          Hospital Names  Temperature(C)  \
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Handling missing values

# %%
# checking if it contains aby NULL values
df.isnull().any()
# Out:
# S#                         False
# Date                       False
# Islamic Date                True
# Blast Day Type              True
# Holiday Type                True
# Time                        True
# City                       False
# Latitude                    True
# Longitude                   True
# Province                   False
# Location                    True
# Location Category           True
# Location Sensitivity        True
# Open/Closed Space           True
# Influencing Event/Event     True
# Target Type                 True
# Targeted Sect if any        True
# Killed Min                  True
# Killed Max                  True
# Injured Min                 True
# Injured Max                 True
# No. of Suicide Blasts       True
# Explosive Weight (max)      True
# Hospital Names              True
# Temperature(C)              True
# Temperature(F)              True
# dtype: bool

# %%
# get the number of missing data points per column
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# S#                           0
# Date                         0
# Islamic Date               156
# Blast Day Type              11
# Holiday Type               420
# Time                       211
# City                         0
# Latitude                     2
# Longitude                    2
# Province                     0
# Location                     3
# Location Category           35
# Location Sensitivity        36
# Open/Closed Space           35
# Influencing Event/Event    305
# Target Type                 26
# Targeted Sect if any        49
# Killed Min                 146
# Killed Max                  16
# Injured Min                131
# Injured Max                 32
# No. of Suicide Blasts       82
# Explosive Weight (max)     323
# Hospital Names             198
# Temperature(C)               5
# Temperature(F)               7
# dtype: int64

# %%
# remove all the rows that contain a missing value
df.dropna()
# Out:
#     S#                    Date         Islamic Date Blast Day Type  \
# 72  73  Friday-November 9-2007  28 SHawwal 1428 A.H        Holiday
#
#    Holiday Type        Time      City  Latitude Longitude Province  ...  \
# 72    Iqbal Day  4:15:00 PM  Peshawar   34.0043   71.5448      KPK  ...
#
#    Targeted Sect if any Killed Min Killed Max Injured Min Injured Max  \
# 72                 None        3.0        4.0         2.0           5
#
#    No. of Suicide Blasts Explosive Weight (max)               Hospital Names  \
# 72                   1.0              5 to 6 Kg  1.Hayatabad Medical Complex
#
#     Temperature(C)  Temperature(F)
# 72          19.445          67.001
#
# [1 rows x 26 columns]

# %%
# remove all columns with at least one missing value
columns_with_na_dropped = df.dropna(axis=1)

# just how much data did we lose?
print(f"Columns in original dataset: {df.shape[1]}")
print(f"Columns with na's dropped: {columns_with_na_dropped.shape[1]}")
# Out:
# Columns in original dataset: 26
# Columns with na's dropped: 4

# %%
df.fillna(0)
# Out:
#       S#                      Date                   Islamic Date  \
# 0      1   Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1      2    Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2      3      Wednesday-May 8-2002              25 safar 1423 A.H
# 3      4       Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4      5        Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# ..   ...                       ...                            ...
# 487  488       Monday-July-17-2017            22 Shawaal 1432 A.H
# 488  489       Monday-July-17-2017            22 Shawaal 1432 A.H
# 489  490       Monday-July-24-2017            29 Shawaal 1432 A.H
# 490  491   Saturday-August-12-2017                              0
# 491  492  Thursday-October-05-2017                              0
#
#     Blast Day Type Holiday Type         Time       City   Latitude  Longitude  \
# 0          Holiday      Weekend            0  Islamabad  33.718000    73.0718
# ...

# %% [markdown]
# ### Replace values

# %%
df['Targeted Sect if any'].value_counts()
# Out:
# None            346
# Shiite           38
# Sunni            38
# Christian         9
# shiite            9
# Shiite/sunni      1
# Jews              1
# Ahmedi            1
# Name: Targeted Sect if any, dtype: int64

# %%
df['Targeted Sect if any'].replace(('shiite', 'Shiite/sunni'), ('Shiite', 'Shiite'), inplace  = True)

# %%
df['Holiday Type'].unique()
# Out:
# array(['Weekend', nan, 'Christmas/birthday of Quaid-e-Azam', 'Ashura',
#        'Eid Milad un-Nabi', 'Iqbal Day', 'Eid-ul-azha', 'Labour Day',
#        'Eid-ul-Fitar', 'Pakistan Day', 'Defence Day',
#        'Christmas/ birthday of Quaid-e-Azam', 'General Elections',
#        'Eid Holidays', 'Ashura Holiday', 'Eid ul Azha Holiday'],
#       dtype=object)

# %%
df['Holiday Type'] = df['Holiday Type'].str.lower()
df['Holiday Type'] = df['Holiday Type'].str.strip()
df['Holiday Type'].unique()
# Out:
# array(['weekend', nan, 'christmas/birthday of quaid-e-azam', 'ashura',
#        'eid milad un-nabi', 'iqbal day', 'eid-ul-azha', 'labour day',
#        'eid-ul-fitar', 'pakistan day', 'defence day',
#        'christmas/ birthday of quaid-e-azam', 'general elections',
#        'eid holidays', 'ashura holiday', 'eid ul azha holiday'],
#       dtype=object)

# %% [markdown]
# ### Changing the Index

# %%
df.index.values
df['S#'].is_unique

df.set_index('S#', inplace=True)

df.reset_index(drop=True, inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Islamic Date', 'Blast Day Type', 'Holiday Type', 'Time',
#        'City', 'Latitude', 'Longitude', 'Province', 'Location',
#        'Location Category', 'Location Sensitivity', 'Open/Closed Space',
#        'Influencing Event/Event', 'Target Type', 'Targeted Sect if any',
#        'Killed Min', 'Killed Max', 'Injured Min', 'Injured Max',
#        'No. of Suicide Blasts', 'Explosive Weight (max)', 'Hospital Names',
#        'Temperature(C)', 'Temperature(F)'],
#       dtype='object')

# %% [markdown]
# ## Data Aggregation

# %%
df_holiday_types = df.groupby(['Holiday Type']).sum()
df_holiday_types.sort_values(["Killed Max"], ascending=False)
# Out:
# <ipython-input-158-196a64788274>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_holiday_types = df.groupby(['Holiday Type']).sum()
#                                         Latitude  Killed Min  Killed Max  \
# Holiday Type
# weekend                              1486.498400       517.0       662.0
# eid milad un-nabi                      90.431300        47.0        66.0
# ashura                                131.542400        54.0        64.0
# eid-ul-azha                            34.150900         0.0        60.0
# christmas/ birthday of quaid-e-azam    34.871800        42.0        47.0
# eid holidays                           62.033300        38.0        47.0
# ashura holiday                         58.457652        32.0        34.0
# ...

# %%
df.groupby('Province')[['Killed Min', 'Injured Min']].sum()
# Out:
#              Killed Min  Injured Min
# Province
# AJK                10.0         96.0
# Balochistan       275.0        550.0
# Baluchistan       501.0       1043.0
# Capital           139.0        520.0
# FATA              560.0       1016.0
# Fata               40.0         60.0
# KPK              2222.0       4811.0
# Punjab            947.0       2547.0
# Sindh             446.0        765.0

# %%
df.groupby('Province')[['Killed Min', 'Injured Min']].agg(['sum', 'mean'])
# Out:
#             Killed Min            Injured Min
#                    sum       mean         sum       mean
# Province
# AJK               10.0  10.000000        96.0  24.000000
# Balochistan      275.0  22.916667       550.0  50.000000
# Baluchistan      501.0  19.269231      1043.0  38.629630
# Capital          139.0  12.636364       520.0  30.588235
# FATA             560.0  12.727273      1016.0  23.090909
# Fata              40.0  40.000000        60.0  60.000000
# KPK             2222.0  12.843931      4811.0  26.146739
# Punjab           947.0  18.940000      2547.0  51.979592
# Sindh            446.0  15.928571       765.0  31.875000

# %% [markdown]
# ## Data Visualisation

# %%
import matplotlib.pyplot as plt

# %%
df['Target Type'].value_counts().plot.bar(figsize = (15, 5), color = 'pink')
plt.title('Targets set by the Terrorists', fontsize = 20)
plt.xlabel('Targets')
plt.ylabel('Count')
plt.show()

# %%
df['Open/Closed Space'].replace(('open', 'closed', 'Open/Closed', 'Open '),('Open', 'Closed', 'Open', 'Open'), inplace = True)

df['Open/Closed Space'].value_counts().plot.pie(colors = ['red', 'grey'], explode = [0, 0.1])
plt.title('A pie Chart representing choice of terrorists for bombing', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# ## BONUS

# %% [markdown]
# ### lambda
#
# In Python, a lambda function is a small, anonymous function that can be defined without a name. Instead of using the def keyword to define a function with a name, you use the lambda keyword to define a function "on the fly".
#
# lambda functions are often used as "throwaway" functions, when you need a quick function to perform a simple operation. They can also be used as arguments to other functions, such as the map(), filter(), and reduce() functions, which take functions as inputs.

# %%
add = lambda x, y: x + y

result = add(2, 3)
print(result)

# %% [markdown]
# ### .apply()
#
# In pandas, the apply() function is used to apply a function along a specific axis of a DataFrame. The apply() function takes a single argument, which is the function to be applied, and applies that function to each row or column of the DataFrame, depending on the value of the axis parameter.
#
# The basic syntax for using the apply() function is:
#
# ```df.apply(func, axis=0)```

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})

def sum_row(row):
    return row["A"] + row["B"]

df["sum"] = df.apply(sum_row, axis=1)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## Reading List
#
# * [Suicide Bombing Attacks(visual & correlations)](https://www.kaggle.com/code/methoomirza/suicide-bombing-attacks-visual-correlations)
#
# ### Data Cleaning Challenge
#
# * [Data Cleaning Challenge: Handling missing values](https://www.kaggle.com/code/rtatman/data-cleaning-challenge-handling-missing-values/notebook)
# * [Data Cleaning Challenge: Scale and Normalize Data](https://www.kaggle.com/code/rtatman/data-cleaning-challenge-scale-and-normalize-data)
# * [Data Cleaning Challenge: Parsing Dates](https://www.kaggle.com/code/rtatman/data-cleaning-challenge-parsing-dates)
# * [Data Cleaning Challenge: Inconsistent Data Entry](https://www.kaggle.com/code/rtatman/data-cleaning-challenge-inconsistent-data-entry)
# * [Data Cleaning Challenge: Character Encodings](https://www.kaggle.com/code/rtatman/data-cleaning-challenge-character-encodings)
